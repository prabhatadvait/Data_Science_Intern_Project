# %% [markdown]
# ## Level 2 Task 1

# %% [raw]
# # Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# # Loading the Dataset

# %%
data = pd.read_csv('task1_level1.csv')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [raw]
# # Percentage offering Table Booking

# %%
table_book_perc = data['Has Table booking'].value_counts(normalize=True)*100
print(table_book_perc)
# Out:
# Has Table booking
# No     87.875615
# Yes    12.124385
# Name: proportion, dtype: float64

# %% [raw]
# # Percentage offering Online Delivery

# %%
online_deliv_perc = data['Has Online delivery'].value_counts(normalize=True)*100
print(online_deliv_perc)
# Out:
# Has Online delivery
# No     74.337766
# Yes    25.662234
# Name: proportion, dtype: float64

# %% [raw]
# # Average rating of Restaurant with or without table booking

# %%
avg_rating_restaurant_table_book = data.groupby('Has Table booking')['Aggregate rating'].mean()
print(avg_rating_restaurant_table_book)
# Out:
# Has Table booking
# No     2.559359
# Yes    3.441969
# Name: Aggregate rating, dtype: float64

# %% [raw]
# # Analyze the availablity of online Delivery with different price ranges

# %%
online_deliv_price = data.groupby('Price range')['Has Online delivery'].value_counts(normalize=True)*100
print(online_deliv_price)
# Out:
# Price range  Has Online delivery
# 1            No                     84.225923
#              Yes                    15.774077
# 2            No                     58.689367
#              Yes                    41.310633
# 3            No                     70.809659
#              Yes                    29.190341
# 4            No                     90.955631
#              Yes                     9.044369
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Price range', hue='Has Online delivery', data=data, palette='coolwarm')

plt.title("Online Delivery Availability by Price Range")
plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")
plt.legend(title="Has Online Delivery", labels=['No', 'Yes'])
plt.show()
